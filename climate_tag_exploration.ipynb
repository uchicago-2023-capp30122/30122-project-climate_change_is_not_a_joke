# %% [markdown]
# The goal of this document is to provide clarity in our decisions and strategy in
# deciding which projects for the Asian Development Bank (ADB) are climate and
#  non-climate realted.
#
# What we do have are known climate projects for the years 2019-2021. However,
# we have scraped data of all projects types from 2011-2023. Our goal is to tag all
# years with climate and non climate realted projects.
#
# Our first strategy was to use already provided atributes "Sectors" to see which
# sectors (Energy, Agriculture, Infrastructure, .etc) contain a majority climate
# realted projects.
#
# We saw that 80+ pectent of climate projects fall within 4 sectors. However,
# This document shows that this assumtion leads to a high false positive rate for
# non-climate projects. When selecting on all projects and selecting on the top
# climate sector there are still a majort of non climate related projects in
# each sector.
#
# The next strategy was to take known climate projects from ADB and to create
# a list of identifying words to catgorize each project. We created a tagging
# function that was able to tag known climate projects with over a 60+ pecent
# accuracy.

# %% [markdown]
# Strategy 1:
#
# Merging known climate projects from 2019-2021 via pandas data frames

# %%
import pandas as pd 


df_2019 = pd.read_csv('project_tracker/data/raw/adb_19-21_climate_data/ADB Climate-2019.csv')
df_2020 = pd.read_csv('project_tracker/data/raw/adb_19-21_climate_data/ADB Climate-2020.csv')
df_2021 = pd.read_csv('project_tracker/data/raw/adb_19-21_climate_data/ADB Climate-2021.csv')

df_2020.head()
# Out:
#   Date Signed Project Number  \
# 0   25-Sep-20      40173-044
# 1   25-Feb-20      48096-002
# 2   17-Sep-20      52286-001
# 3   19-Jun-20      47279-002
# 4   19-Jun-20      47279-002
#
#                                         Project Name Country Code  \
# 0  Highlands Region Road Improvement Investment P...          PNG
# 1  Arghandab Integrated Water Resources Developme...          AFG
# 2  Central Asia Regional Economic Cooperation Cor...          KAZ
# 3         Karachi Bus Rapid Transit Red Line Project          PAK
# 4         Karachi Bus Rapid Transit Red Line Project          PAK
#
#   Developing Member Country                 Region Department  \
# 0          Papua New Guinea                Pacific       PARD
# 1               Afghanistan  Central and West Asia       CWRD
# 2                Kazakhstan  Central and West Asia       CWRD
# 3                  Pakistan  Central and West Asia       CWRD
# 4                  Pakistan  Central and West Asia       CWRD
#
# ...

# %% [markdown]
# Looking for any differances in data frame. 2020 has an extra column " Other Sector" and multiple NA columns

# %%
df_2020.dropna(how='all', axis=1, inplace=True)

new_df_2020 = df_2020.drop(['Other Sector(s) Covered'], axis = 1)

new_df_2020.head()
# Out:
#   Date Signed Project Number  \
# 0   25-Sep-20      40173-044
# 1   25-Feb-20      48096-002
# 2   17-Sep-20      52286-001
# 3   19-Jun-20      47279-002
# 4   19-Jun-20      47279-002
#
#                                         Project Name Country Code  \
# 0  Highlands Region Road Improvement Investment P...          PNG
# 1  Arghandab Integrated Water Resources Developme...          AFG
# 2  Central Asia Regional Economic Cooperation Cor...          KAZ
# 3         Karachi Bus Rapid Transit Red Line Project          PAK
# 4         Karachi Bus Rapid Transit Red Line Project          PAK
#
#   Developing Member Country                 Region Department  \
# 0          Papua New Guinea                Pacific       PARD
# 1               Afghanistan  Central and West Asia       CWRD
# 2                Kazakhstan  Central and West Asia       CWRD
# 3                  Pakistan  Central and West Asia       CWRD
# 4                  Pakistan  Central and West Asia       CWRD
#
# ...

# %%
frames = [df_2019, new_df_2020, df_2021]

climate_data = pd.concat(frames)


climate_data.head()
# Out:
#   Date Signed Project Number  \
# 0  8-Feb-2019      47037-005
# 1  8-Mar-2019      42265-025
# 2  5-Jan-2019      48098-002
# 3  5-Jan-2019      48098-002
# 4  5-Jan-2019      48098-002
#
#                                         Project Name Country Code  \
# 0  Green Power Development and Energy Efficiency ...          SRI
# 1  Assam Urban Infrastructure Investment Program ...          IND
# 2  Balochistan Water Resources Development Sector...          PAK
# 3  Balochistan Water Resources Development Sector...          PAK
# 4  Balochistan Water Resources Development Sector...          PAK
#
#   Developing Member Country                 Region Department  \
# 0                 Sri Lanka             South Asia       SARD
# 1                     India             South Asia       SARD
# 2                  Pakistan  Central and West Asia       CWRD
# 3                  Pakistan  Central and West Asia       CWRD
# 4                  Pakistan  Central and West Asia       CWRD
#
# ...

# %% [markdown]
# Adding a new column as an Identifier to known climate data frame

# %%
climate_data['Climate Project'] = 'Yes'
climate_data.head()
# Out:
#   Date Signed Project Number  \
# 0  8-Feb-2019      47037-005
# 1  8-Mar-2019      42265-025
# 2  5-Jan-2019      48098-002
# 3  5-Jan-2019      48098-002
# 4  5-Jan-2019      48098-002
#
#                                         Project Name Country Code  \
# 0  Green Power Development and Energy Efficiency ...          SRI
# 1  Assam Urban Infrastructure Investment Program ...          IND
# 2  Balochistan Water Resources Development Sector...          PAK
# 3  Balochistan Water Resources Development Sector...          PAK
# 4  Balochistan Water Resources Development Sector...          PAK
#
#   Developing Member Country                 Region Department  \
# 0                 Sri Lanka             South Asia       SARD
# 1                     India             South Asia       SARD
# 2                  Pakistan  Central and West Asia       CWRD
# 3                  Pakistan  Central and West Asia       CWRD
# 4                  Pakistan  Central and West Asia       CWRD
#
# ...

# %% [markdown]
# Adding identifying Column to all projects data frame

# %%
scrape_df = pd.read_csv('project_tracker/data/raw/clean_df.csv')

scrape_df['Climate Project'] = 'Maybe'
scrape_df.head()
# Out:
#        Country                 Region  \
# 0     Regional               Regional
# 1  Philippines        South East Asia
# 2   Uzbekistan  Central and West Asia
# 3     Regional               Regional
# 4   Kazakhstan  Central and West Asia
#
#                                         Project Name  \
# 0       Creating Knowledge Solutions for the Pacific
# 1  Strengthening Infrastructure Capacity and Inno...
# 2  Supporting the Improving the Governance Enviro...
# 3  Subproject 13: Supporting Implementation of St...
# 4  Opportunities to Accelerate Coal to Clean Powe...
#
#                                  Project Description  Status  \
# 0  The knowledge and support technical assistance...  Active
# 1  The proposed Technical Assistance (TA) will su...  Active
# 2  With the support of ADB's Improving the Govern...  Active
# 3  Subproject 13 will facilitate gender mainstrea...  Active
# 4                                                NaN  Active
#
# ...

# %% [markdown]
# Now looking at similar column to join dataframes for known projects and all
# projects

# %%
header_lst = []
for head in scrape_df.head():
    header_lst.append(head)
print(header_lst)

other_lst = []
for head in climate_data.head():
    other_lst.append(head)
print(other_lst)
# Out:
# ['Country', 'Region', 'Project Name', 'Project Description', 'Status', 'Project URL', 'Effective Date', 'Commitment Amount', 'Pre/Post Paris Agreement', 'Year', 'Sector', 'Climate Project']
# ['Date Signed', 'Project Number', 'Project Name', 'Country Code', 'Developing Member Country', 'Region', 'Department', 'Operations Division', 'Category Type (Sovereign/Nonsovereign Financing)', 'Project Financing Amount ($ million)', 'Mode of Financial Assistance', 'Product Type', 'Loan/Grant/Investment/Approval Number', 'Project Financing Type', 'Fund Source', 'Signed amount ($ million)', 'Primary Sector', 'Sector', 'Climate Change Response', 'Climate Change Impact on the Project', 'Adaptation Finance ($ million)', 'Mitigation Finance ($ million)', 'Type of Financing', 'Currency', 'Project URL', 'Climate Project']

# %% [markdown]
# Now we are dropping duplicates of known climate data and normalizing columns to
# merge both data frames.
#
# In  addition, lookng at the proportion sectors for climate projects. We can see
# the top four sectors have ~ 80% of pojects.
#
# For all projects there is a slightly more balanced proportion of projects
# per sector

# %%
rename_climate_date = climate_data.rename(columns={ "Date Signed": "Effective Date" }, errors="raise")
other_lst = []
rename_climate_date.head()



rename_climate_date = rename_climate_date[['Effective Date','Project Name','Sector','Climate Project','Project URL']].copy()
rename_climate_date = rename_climate_date.drop_duplicates(subset='Project URL', keep="first")
print(len(rename_climate_date['Project Name']))
compare_scrape = scrape_df[['Effective Date','Project Name','Sector','Climate Project','Project URL']].copy()



print(rename_climate_date ['Sector'].value_counts(1))
print(compare_scrape['Sector'].value_counts(1))
# Out:
# 416
# Energy                                                  0.278846
# Agriculture, natural resources and rural development    0.177885
# Transport                                               0.175481
# Water and other urban infrastructure and services       0.158654
# Public sector management                                0.067308
# Finance                                                 0.062500
# Health                                                  0.028846
# Education                                               0.021635
# Industry and trade                                      0.014423
# Information and communication technology                0.007212
# Multisector                                             0.007212
# Name: Sector, dtype: float64
# Agriculture, natural resources and rural development    0.172090
# Public sector management                                0.166305
# Transport                                               0.144975
# ...

# %% [markdown]
# Merging both known and all poject data frame and checking for duplicates via
# urls.

# %%
new_frames = [rename_climate_date ,compare_scrape]

campare_sectors = pd.concat(new_frames)
max(campare_sectors['Project URL'].value_counts())
# Out:
# 1

# %% [markdown]
# Now selecting top sector for climate project "Energy" with combined data.

# %%
campare_sectors['Sector'].value_counts(1)


energy_df =campare_sectors[campare_sectors['Sector'] == 'Energy'] 
energy_date = energy_df[(energy_df['Effective Date'] > '01-Jan-2019') & (energy_df['Effective Date'] < '12-Dec-2021')]
energy_date['Climate Project'].value_counts(1)
# Out:
# Maybe    0.831081
# Yes      0.168919
# Name: Climate Project, dtype: float64

# %% [markdown]
# Now selecting top sector for climate project "'Agriculture, natural resources
# and rural development'" with combined data.

# %%
ag_df =campare_sectors[campare_sectors['Sector'] == 'Agriculture, natural resources and rural development'] 
ag_date = ag_df[(ag_df['Effective Date'] > '01-Jan-2019') & (ag_df['Effective Date'] < '12-Dec-2021')]
ag_df['Climate Project'].value_counts(1)
# Out:
# Maybe    0.865455
# Yes      0.134545
# Name: Climate Project, dtype: float64

# %% [markdown]
# Conclusion:
#
# This assumtion of using the Sector attribute is highly inaccurate.
# Even though 80 pecent of Climate project fall under four Sector categories
# Looking at the top sector Energy and observing the split of known climate
# projects and non climate projects for years of known climate projects.
# Over 80 pecent of the projects are still non climate related which would lead to
# a high false positive rate with this assumtion.

# %% [markdown]
# Strategy 2:
#
# Our next strategy was to tag projects based off of climate tokens.
#
# We did this by combining the known climate data frames and creating tokens from
# the project names. We then found what tokens occured most frquently across all
# projects. From there we then limited the list for words related to climate.
#
# Next we created a function that then used this list to classify a single project.

# %%
import spacy.cli
from project_tracker.load_and_clean import Cleaner


def add_climate_tag(df):

    """
    Creates new column and determines if project is climate realted based off
    of list of Tag words 

    Input:
        df(pandas data frame): data frame

    Return:
        data frame 
    """

    sp = spacy.load("en_core_web_lg")
    tag = pd.read_csv('data/raw/adb_19-21_climate_data/climate_tag_words.csv')

    print(tag)
    
    for index, row in df.iterrows():

        doc = sp(row['Project Name'])
        words = [token.text for token in doc if not token.is_stop and not token.is_punct and not token.like_num]
        for word in words:
            if word == '2)-' or word == '1)-':
                continue
            if tag["Tag"].str.contains(word).any():
                df.loc[index,['Climate-Related']] = 'Yes'
                break
            else:
                df.loc[index,['Climate-Related']] = 'No'   
    return df 


climate_tag = Cleaner.merg_climate_df()
climate_tag = add_climate_tag(climate_tag)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 38
#      34                 df.loc[index,['Climate-Related']] = 'No'
#      35     return df
# ---> 38 climate_tag = Cleaner.merg_climate_df()
#      39 climate_tag = add_climate_tag(climate_tag)
#
# File ~/capp30122/30122-project-climate_change_is_not_a_joke/project_tracker/load_and_clean/Cleaner.py:85, in merg_climate_df()
#      84 def merg_climate_df():
# ---> 85     df_2019 = pd.read_csv('adb_19-21_climate_data/ADB Climate-2019.csv')
#      86     df_2020 = pd.read_csv('adb_19-21_climate_data/ADB Climate-2020.csv')
#      87     df_2021 = pd.read_csv('adb_19-21_climate_data/ADB Climate-2021.csv')
#
# File /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
# ...

# %%
climate_tag['Climate-Related'].value_counts(1)
# Out:
# Yes    0.620455
# No     0.379545
# Name: Climate-Related, dtype: float64

# %% [markdown]
# Conclusion:
#
# We were able to capture over 60 percent of the known climate projects with the
# tagging method. Even though we are missing 40 percent of climate projects we
# were consistent in the approach meaning we used this fucntion across all
# ADB projects. In conclusion, we were consistent with the missing data and
# because of this consistency we belive this approach was ultimately more
# accurate.
